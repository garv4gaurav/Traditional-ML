# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
database_path = "/content/drive/My Drive/DBs/simple_linear_regression/"

# %%
database = pd.read_csv(database_path+"Salary_Data.csv")

# %%
database.head(5)
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
X = database.iloc[:, :-1].values
y = database.iloc[:, -1].values
#print(X,y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 2)

# %% [markdown]
# Feature Scaling(StandScaler) is not used in here and in most of the cases as it is automatically taken care by the native libraries itself.

# %%
#sc_x = StandardScaler()
#sc_y = StandardScaler()
#X_train = sc_x.fit_transform(X_train)
#X_test = sc_x.transform(X_test)
#y_train = sc_y.fit_transform(y_train)

# %%
model_SLR = LinearRegression()

# %%
model_SLR.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = model_SLR.predict(X_test)

# %%
model_SLR.score(X_test, y_test)
# Out:
# 0.8886956733784563
